# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("../13-HeapGlobal/musicbrainz-200-A01.csv.dapo", sep=",", encoding="utf-8", keep_default_na=False, na_values=[''], dtype={'TID': int, 'CID': str, 'CTID': str, 'SourceID': str, 'id': str, 'number': str, 'title': str, 'length': str, 'artist': str, 'album': str, 'year': str, 'language': str})
dataset = dataset.fillna('-')
dataset.head(2)
# Out:
#    TID    CID CTID SourceID               id number  \
# 0    1      1    1        1       WoM5452845      0
# 1    2  32522    4        2  MBox36398328-HH     11
#
#                                                title length            artist  \
# 0  L'enfant aux yeux d'Italie (De vous à elle en ...  03:39  Daniel Balavoine
# 1                        Silver Forest - 双剣乱舞 みょん＆me    229                 -
#
#                                 album  year  language
# 0  De vous à elle en passsant par moi  1975         -
# 1       Silver Forest 2006-2012 BEST1    12  Japanese

# %%
import uuid
import json

# Select 50% of records randomly
selected_indices = dataset.index[np.random.rand(len(dataset)) < 0.5]
df_selected = dataset.loc[selected_indices]

def perturb_record_with_id(record, original_id):
    perturbed1 = record.copy()
    perturbed2 = record.copy()
    
    perturbed1['artist'] = str(perturbed1['artist']).lower()
    perturbed2['year'] += "1"

    new_id1 = f"novo1{original_id}"
    new_id2 = f"novo2{original_id}"
    
    perturbed1['TID2'] = new_id1
    perturbed2['TID2'] = new_id2

    return [(new_id1, perturbed1), (new_id2, perturbed2)]

ground_truth = {}
perturbed_records = []

for idx, record in df_selected.iterrows():
    original_id = record['TID']
    perturbed = perturb_record_with_id(record, original_id)
    
    
    for new_id, perturbed_record in perturbed:
        ground_truth[new_id] = original_id
        perturbed_records.append(perturbed_record)

# Export ground truth to CSV with column headers
with open('ground_truth_music_brainz.csv', 'w') as f:
    f.write("novoidmusic1,antigoidmusic2\n")
    for new_id, original_id in ground_truth.items():
        f.write(f"{new_id},{original_id}\n")

# Create DataFrame for perturbed records and export to CSV
df_perturbed = pd.DataFrame(perturbed_records)
df_perturbed.to_csv('music_brainz-simple-mutated.csv', index=False)

# %%
df_perturbed.shape, dataset.shape
# Out:
# ((193470, 13), (193750, 12))

# %%
df_perturbed.head()
# Out:
#    TID CID CTID SourceID           id number  \
# 0    1   1    1        1   WoM5452845      0
# 0    1   1    1        1   WoM5452845      0
# 5    6   3    1        5      4489993     10
# 5    6   3    1        5      4489993     10
# 9   10   5    1        4  160109-A070      6
#
#                                                title   length  \
# 0  L'enfant aux yeux d'Italie (De vous à elle en ...    03:39
# 0  L'enfant aux yeux d'Italie (De vous à elle en ...    03:39
# 5                                         Your Grace   166000
# 5                                         Your Grace   166000
# 9                                 006-Try_(acoustic)  unknown
#
#              artist                                              album   year  \
# 0  daniel balavoine                 De vous à elle en passsant par moi   1975
# 0  Daniel Balavoine                 De vous à elle en passsant par moi  19751
# 5    kathy troccoli                                            Comfort   2005
# 5    Kathy Troccoli                                            Comfort  20051
# 9        neil young  2008-02-15: Le Grand Rex, Paris, France (unknown)   null
#
#   language     TID2
# 0        -   novo11
# 0        -   novo21
# 5  English   novo16
# 5  English   novo26
# 9     Eng.  novo110

# %%
dataset.head()
# Out:
#    TID    CID CTID SourceID               id number  \
# 0    1      1    1        1       WoM5452845      0
# 1    2  32522    4        2  MBox36398328-HH     11
# 2    3  53749    2        3     4382873MB-01      2
# 3    4      2    1        3             unk.     17
# 4    5  31368    3        4      215214-A048      6
#
#                                                title    length  \
# 0  L'enfant aux yeux d'Italie (De vous à elle en ...     03:39
# 1                        Silver Forest - 双剣乱舞 みょん＆me       229
# 2                            shabnavard - Chavoush 2    27.183
# 3            Mustard Gas - There and Back Again Lane      2.15
# 4                           006-Immer bis ich reier'  3m 48sec
#
#              artist                               album  year  language
# 0  Daniel Balavoine  De vous à elle en passsant par moi  1975         -
# 1                 -       Silver Forest 2006-2012 BEST1    12  Japanese
# 2       شهرام ناظری                                   -     -   Persian
# 3  Action Painting!                                   -   '95   English
# 4          Nordwand           Das Pinke Album (unknown)  null      Ger.

# %%
# Check duplicates for all columns
print("Duplicate Analysis for All Columns")
print("=" * 80)

for column in dataset.columns:
    print(f"\nColumn: {column}")
    print("-" * 80)
    
    # Count duplicates
    value_counts = dataset[column].value_counts()
    total_values = len(dataset[column])
    unique_values = dataset[column].nunique()
    null_values = dataset[column].isnull().sum()
    duplicate_values = value_counts[value_counts > 1]
    
    print(f"Total values: {total_values}")
    print(f"Unique values: {unique_values}")
    print(f"Null values: {null_values}")
    print(f"Values appearing more than once: {len(duplicate_values)}")
    print(f"Total duplicate entries: {duplicate_values.sum() - len(duplicate_values)}")
    
    # Show top 10 most frequent duplicate values
    if len(duplicate_values) > 0:
        print(f"\nTop 10 most frequent duplicate values:")
        print(duplicate_values.head(10))
# Out:
# Duplicate Analysis for All Columns
# ================================================================================
#
# Column: TID
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 193750
# Null values: 0
# Values appearing more than once: 0
# Total duplicate entries: 0
#
# Column: CID
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 100000
# Null values: 0
# Values appearing more than once: 50000
# Total duplicate entries: 93750
#
# Top 10 most frequent duplicate values:
# CID
# 73510    5
# 12843    5
# 42053    5
# 12821    5
# 48318    5
# 13582    5
# 12823    5
# 50160    5
# 88321    5
# 12825    5
# Name: count, dtype: int64
#
# Column: CTID
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 5
# Null values: 0
# Values appearing more than once: 5
# Total duplicate entries: 193745
#
# Top 10 most frequent duplicate values:
# CTID
# 1    100000
# 2     50000
# 3     25000
# 4     12500
# 5      6250
# Name: count, dtype: int64
#
# Column: SourceID
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 5
# Null values: 0
# Values appearing more than once: 5
# Total duplicate entries: 193745
#
# Top 10 most frequent duplicate values:
# SourceID
# 4    38857
# 5    38801
# 1    38787
# 3    38670
# 2    38635
# Name: count, dtype: int64
#
# Column: id
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 192054
# Null values: 1045
# Values appearing more than once: 41
# Total duplicate entries: 651
#
# Top 10 most frequent duplicate values:
# id
# unknown    155
# unk.       145
# n.a.       133
# -A          49
# MB-         47
# WoM         38
# MBox-HH     31
# English     14
# 1            6
# 1998         4
# Name: count, dtype: int64
#
# Column: number
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 1409
# Null values: 1083
# Values appearing more than once: 603
# Total duplicate entries: 191258
#
# Top 10 most frequent duplicate values:
# number
# 1     12522
# 2     12166
# 4     11662
# 3     11539
# 5     10314
# 6      9831
# 7      9485
# 8      9307
# 9      8759
# 10     7894
# Name: count, dtype: int64
#
# Column: title
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 186311
# Null values: 789
# Values appearing more than once: 3506
# Total duplicate entries: 6650
#
# Top 10 most frequent duplicate values:
# title
# unknown       179
# n.a.          164
# unk.          137
# [untitled]    110
# 002-           69
# 004-           54
# 001-           54
# [silence]      52
# 006-           50
# 003-           46
# Name: count, dtype: int64
#
# Column: length
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 25451
# Null values: 10730
# Values appearing more than once: 10652
# Total duplicate entries: 157569
#
# Top 10 most frequent duplicate values:
# length
# unknown     3505
# 00:00       3364
# 0m 30sec     282
# 30000        274
# 00:30        268
# 0.5          263
# 30           251
# 3m 0sec      218
# 218          200
# 03:31        196
# Name: count, dtype: int64
#
# Column: artist
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 65979
# Null values: 39965
# Values appearing more than once: 28005
# Total duplicate entries: 87806
#
# Top 10 most frequent duplicate values:
# artist
# Johann Sebastian Bach      758
# [unknown]                  660
# Wolfgang Amadeus Mozart    524
# Ludwig van Beethoven       367
#                            288
# Antonio Vivaldi            249
# U2                         180
# Elvis Presley              166
# Georg Friedrich Händel     161
# Nirvana                    161
# Name: count, dtype: int64
#
# Column: album
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 109649
# Null values: 37607
# Values appearing more than once: 28451
# Total duplicate entries: 46494
#
# Top 10 most frequent duplicate values:
# album
# Greatest Hits              208
# n.a.                       182
# unk.                       167
# unknown                    146
# Live                        94
# The Collection              74
# The Best Of                 64
# The Ultimate Collection     62
# Anthology                   50
# Demo                        43
# Name: count, dtype: int64
#
# Column: year
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 1367
# Null values: 77615
# Values appearing more than once: 584
# Total duplicate entries: 114768
#
# Top 10 most frequent duplicate values:
# year
# 2006    3234
# 2008    3157
# 2005    3108
# 2007    3107
# 2009    2881
# 2004    2850
# 2010    2813
# 2003    2744
# 2002    2446
# 2011    2378
# Name: count, dtype: int64
#
# Column: language
# --------------------------------------------------------------------------------
# Total values: 193750
# Unique values: 2875
# Null values: 45007
# Values appearing more than once: 1239
# Total duplicate entries: 145868
#
# Top 10 most frequent duplicate values:
# language
# English                 74057
# Eng.                    24791
# German                   3975
# [Multiple languages]     3362
# French                   3207
# unknown                  2976
# Spanish                  2966
# Japanese                 2802
# Ger.                     1361
# Italian                  1314
# Name: count, dtype: int64

# %% [markdown]
# # Modificando NCVR

# %%
data = pd.read_csv('./ncvoter42.txt', sep='\t',encoding='latin1')
data
# Out:
#        county_id county_desc  voter_reg_num      ncid   last_name first_name  \
# 0             42     HALIFAX         100702   BZ61829       AARON     RHANDA
# 1             42     HALIFAX         107751   BZ75895       AASBY    BRANDON
# 2             42     HALIFAX         104490   BZ73617     ABAKKAL      NOURA
# 3             42     HALIFAX          97201   BZ68595       ABBAN    SHANNAN
# 4             42     HALIFAX          68003   BZ45167      ABBOTT        AMY
# ...          ...         ...            ...       ...         ...        ...
# 40837         42     HALIFAX         107670   BZ45511   ZSEBEHAZY     ROBERT
# 40838         42     HALIFAX         106555   BZ74992     ZUBAIDI       AFAF
# 40839         42     HALIFAX          21018   BZ10671      ZUCKER     DIANNE
# 40840         42     HALIFAX          21011   BZ10666      ZUCKER     ROBERT
# 40841         42     HALIFAX         110115  EH271079  ZUMBRUNNEN     DANIEL
#
#          middle_name name_suffix_lbl status_cd voter_status_desc  ...  \
# 0        FAITH THORA             NaN         A            ACTIVE  ...
# 1                NaN             NaN         A            ACTIVE  ...
# 2                NaN             NaN         A            ACTIVE  ...
# 3              JANAY             NaN         I          INACTIVE  ...
# 4              CLARY             NaN         D            DENIED  ...
# ...              ...             ...       ...               ...  ...
# 40837           JOHN             NaN         A            ACTIVE  ...
# 40838  MOHAMED SALEH             NaN         A            ACTIVE  ...
# 40839            NaN             NaN         A            ACTIVE  ...
# 40840              N             NaN         A            ACTIVE  ...
# 40841            NaN              JR         A            ACTIVE  ...
#
#       sanit_dist_abbrv       sanit_dist_desc rescue_dist_abbrv  \
# 0                  SAN  RR SANITARY DISTRICT               NaN
# 1                  NaN                   NaN               NaN
# 2                  SAN  RR SANITARY DISTRICT               NaN
# 3                  SAN  RR SANITARY DISTRICT               NaN
# 4                  NaN                   NaN               NaN
# ...                ...                   ...               ...
# 40837              NaN                   NaN               NaN
# 40838              SAN  RR SANITARY DISTRICT               NaN
# 40839              SAN  RR SANITARY DISTRICT               NaN
# 40840              SAN  RR SANITARY DISTRICT               NaN
# 40841              NaN                   NaN               NaN
#
#       rescue_dist_desc munic_dist_abbrv         munic_dist_desc dist_1_abbrv  \
# 0                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 1                  NaN              NaN                     NaN          7.0
# 2                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 3                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 4                  NaN              NaN                     NaN          NaN
# ...                ...              ...                     ...          ...
# 40837              NaN              NaN                     NaN          7.0
# 40838              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40839              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40840              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40841              NaN              ENF         TOWN OF ENFIELD          7.0
#
#                     dist_1_desc vtd_abbrv vtd_desc
# 0      PROSECUTORIAL DISTRICT 7      RR-8     RR 8
# 1      PROSECUTORIAL DISTRICT 7      RR-9     RR 9
# 2      PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 3      PROSECUTORIAL DISTRICT 7      RR-1     RR 1
# 4                           NaN       NaN      NaN
# ...                         ...       ...      ...
# 40837  PROSECUTORIAL DISTRICT 7     WEL-3    WEL 3
# 40838  PROSECUTORIAL DISTRICT 7      RR-1     RR 1
# 40839  PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 40840  PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 40841  PROSECUTORIAL DISTRICT 7     ENF-3    ENF 3
#
# [40842 rows x 67 columns]

# %%
data.loc[0].to_string()
# Out:
# 'county_id                                               42\ncounty_desc                                        HALIFAX\nvoter_reg_num                                       100702\nncid                                               BZ61829\nlast_name                                            AARON\nfirst_name                                          RHANDA\nmiddle_name                                    FAITH THORA\nname_suffix_lbl                                        NaN\nstatus_cd                                                A\nvoter_status_desc                                   ACTIVE\nreason_cd                                               AV\nvoter_status_reason_desc                          VERIFIED\nres_street_address                  1327  WASHINGTON ST   \nres_city_desc                               ROANOKE RAPIDS\nstate_cd                                                NC\nzip_code                                           27870.0\nmail_addr1                              1327 WASHINGTON ST\nmail_addr2                                             NaN\nmail_addr3                                             NaN\nmail_addr4                                             NaN\nmail_city                                   ROANOKE RAPIDS\nmail_state                                              NC\nmail_zipcode                                         27870\nfull_phone_number                             2526733107.0\nconfidential_ind                                         N\nregistr_dt                                      11/25/2019\nrace_code                                                B\nethnic_code                                             NL\nparty_cd                                               UNA\ngender_code                                              F\nbirth_year                                            1992\nage_at_year_end                                         32\nbirth_state                                             OC\ndrivers_lic                                              Y\nprecinct_abbrv                                        RRCE\nprecinct_desc                       ROANOKE RAPIDS CENTRAL\nmunicipality_abbrv                                      RR\nmunicipality_desc                   CITY OF ROANOKE RAPIDS\nward_abbrv                                            RRW2\nward_desc                                            RRW02\ncong_dist_abbrv                                        1.0\nsuper_court_abbrv                                      07A\njudic_dist_abbrv                                       7.0\nnc_senate_abbrv                                        2.0\nnc_house_abbrv                                        27.0\ncounty_commiss_abbrv                                  CCD3\ncounty_commiss_desc         COUNTY COMMISSIONER DISTRICT 3\ntownship_abbrv                                         9.0\ntownship_desc                               ROANOKE RAPIDS\nschool_dist_abbrv                                     RRSC\nschool_dist_desc                     ROANOKE RAPIDS SCHOOL\nfire_dist_abbrv                                        NaN\nfire_dist_desc                                         NaN\nwater_dist_abbrv                                       NaN\nwater_dist_desc                                        NaN\nsewer_dist_abbrv                                       NaN\nsewer_dist_desc                                        NaN\nsanit_dist_abbrv                                       SAN\nsanit_dist_desc                       RR SANITARY DISTRICT\nrescue_dist_abbrv                                      NaN\nrescue_dist_desc                                       NaN\nmunic_dist_abbrv                                        RR\nmunic_dist_desc                     CITY OF ROANOKE RAPIDS\ndist_1_abbrv                                           7.0\ndist_1_desc                       PROSECUTORIAL DISTRICT 7\nvtd_abbrv                                             RR-8\nvtd_desc                                ...

# %%
selected_indices = data.index[np.random.rand(len(data)) < 0.5]
df_selected = data.loc[selected_indices]

# %%
df_selected
# Out:
#        county_id county_desc  voter_reg_num      ncid   last_name first_name  \
# 2             42     HALIFAX         104490   BZ73617     ABAKKAL      NOURA
# 4             42     HALIFAX          68003   BZ45167      ABBOTT        AMY
# 6             42     HALIFAX          65983   BZ43147      ABBOTT     DAMIEN
# 7             42     HALIFAX          92176   BZ65026      ABBOTT      ERICA
# 8             42     HALIFAX          83239   BZ58220      ABBOTT      JOSIE
# ...          ...         ...            ...       ...         ...        ...
# 40836         42     HALIFAX         102061   BZ71995       ZOTOS     KELSEY
# 40837         42     HALIFAX         107670   BZ45511   ZSEBEHAZY     ROBERT
# 40838         42     HALIFAX         106555   BZ74992     ZUBAIDI       AFAF
# 40839         42     HALIFAX          21018   BZ10671      ZUCKER     DIANNE
# 40841         42     HALIFAX         110115  EH271079  ZUMBRUNNEN     DANIEL
#
#          middle_name name_suffix_lbl status_cd voter_status_desc  ...  \
# 2                NaN             NaN         A            ACTIVE  ...
# 4              CLARY             NaN         D            DENIED  ...
# 6                  S             NaN         A            ACTIVE  ...
# 7             DENEEN             NaN         I          INACTIVE  ...
# 8            EDWARDS             NaN         I          INACTIVE  ...
# ...              ...             ...       ...               ...  ...
# 40836      ANN-MARIE             NaN         I          INACTIVE  ...
# 40837           JOHN             NaN         A            ACTIVE  ...
# 40838  MOHAMED SALEH             NaN         A            ACTIVE  ...
# 40839            NaN             NaN         A            ACTIVE  ...
# 40841            NaN              JR         A            ACTIVE  ...
#
#       sanit_dist_abbrv       sanit_dist_desc rescue_dist_abbrv  \
# 2                  SAN  RR SANITARY DISTRICT               NaN
# 4                  NaN                   NaN               NaN
# 6                  NaN                   NaN               NaN
# 7                  SAN  RR SANITARY DISTRICT               NaN
# 8                  SAN  RR SANITARY DISTRICT               NaN
# ...                ...                   ...               ...
# 40836              SAN  RR SANITARY DISTRICT               NaN
# 40837              NaN                   NaN               NaN
# 40838              SAN  RR SANITARY DISTRICT               NaN
# 40839              SAN  RR SANITARY DISTRICT               NaN
# 40841              NaN                   NaN               NaN
#
#       rescue_dist_desc munic_dist_abbrv         munic_dist_desc dist_1_abbrv  \
# 2                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 4                  NaN              NaN                     NaN          NaN
# 6                  NaN              NaN                     NaN          7.0
# 7                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 8                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# ...                ...              ...                     ...          ...
# 40836              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40837              NaN              NaN                     NaN          7.0
# 40838              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40839              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40841              NaN              ENF         TOWN OF ENFIELD          7.0
#
#                     dist_1_desc vtd_abbrv vtd_desc
# 2      PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 4                           NaN       NaN      NaN
# 6      PROSECUTORIAL DISTRICT 7     LIT-1    LIT 1
# 7      PROSECUTORIAL DISTRICT 7      RR-7     RR 7
# 8      PROSECUTORIAL DISTRICT 7     WEL-3    WEL 3
# ...                         ...       ...      ...
# 40836  PROSECUTORIAL DISTRICT 7      RR-5     RR 5
# 40837  PROSECUTORIAL DISTRICT 7     WEL-3    WEL 3
# 40838  PROSECUTORIAL DISTRICT 7      RR-1     RR 1
# 40839  PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 40841  PROSECUTORIAL DISTRICT 7     ENF-3    ENF 3
#
# [20446 rows x 67 columns]

# %%
df_selected
# Out:
#        county_id county_desc  voter_reg_num      ncid   last_name first_name  \
# 2             42     HALIFAX         104490   BZ73617     ABAKKAL      NOURA
# 4             42     HALIFAX          68003   BZ45167      ABBOTT        AMY
# 6             42     HALIFAX          65983   BZ43147      ABBOTT     DAMIEN
# 7             42     HALIFAX          92176   BZ65026      ABBOTT      ERICA
# 8             42     HALIFAX          83239   BZ58220      ABBOTT      JOSIE
# ...          ...         ...            ...       ...         ...        ...
# 40836         42     HALIFAX         102061   BZ71995       ZOTOS     KELSEY
# 40837         42     HALIFAX         107670   BZ45511   ZSEBEHAZY     ROBERT
# 40838         42     HALIFAX         106555   BZ74992     ZUBAIDI       AFAF
# 40839         42     HALIFAX          21018   BZ10671      ZUCKER     DIANNE
# 40841         42     HALIFAX         110115  EH271079  ZUMBRUNNEN     DANIEL
#
#          middle_name name_suffix_lbl status_cd voter_status_desc  ...  \
# 2                NaN             NaN         A            ACTIVE  ...
# 4              CLARY             NaN         D            DENIED  ...
# 6                  S             NaN         A            ACTIVE  ...
# 7             DENEEN             NaN         I          INACTIVE  ...
# 8            EDWARDS             NaN         I          INACTIVE  ...
# ...              ...             ...       ...               ...  ...
# 40836      ANN-MARIE             NaN         I          INACTIVE  ...
# 40837           JOHN             NaN         A            ACTIVE  ...
# 40838  MOHAMED SALEH             NaN         A            ACTIVE  ...
# 40839            NaN             NaN         A            ACTIVE  ...
# 40841            NaN              JR         A            ACTIVE  ...
#
#       sanit_dist_abbrv       sanit_dist_desc rescue_dist_abbrv  \
# 2                  SAN  RR SANITARY DISTRICT               NaN
# 4                  NaN                   NaN               NaN
# 6                  NaN                   NaN               NaN
# 7                  SAN  RR SANITARY DISTRICT               NaN
# 8                  SAN  RR SANITARY DISTRICT               NaN
# ...                ...                   ...               ...
# 40836              SAN  RR SANITARY DISTRICT               NaN
# 40837              NaN                   NaN               NaN
# 40838              SAN  RR SANITARY DISTRICT               NaN
# 40839              SAN  RR SANITARY DISTRICT               NaN
# 40841              NaN                   NaN               NaN
#
#       rescue_dist_desc munic_dist_abbrv         munic_dist_desc dist_1_abbrv  \
# 2                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 4                  NaN              NaN                     NaN          NaN
# 6                  NaN              NaN                     NaN          7.0
# 7                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 8                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# ...                ...              ...                     ...          ...
# 40836              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40837              NaN              NaN                     NaN          7.0
# 40838              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40839              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40841              NaN              ENF         TOWN OF ENFIELD          7.0
#
#                     dist_1_desc vtd_abbrv vtd_desc
# 2      PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 4                           NaN       NaN      NaN
# 6      PROSECUTORIAL DISTRICT 7     LIT-1    LIT 1
# 7      PROSECUTORIAL DISTRICT 7      RR-7     RR 7
# 8      PROSECUTORIAL DISTRICT 7     WEL-3    WEL 3
# ...                         ...       ...      ...
# 40836  PROSECUTORIAL DISTRICT 7      RR-5     RR 5
# 40837  PROSECUTORIAL DISTRICT 7     WEL-3    WEL 3
# 40838  PROSECUTORIAL DISTRICT 7      RR-1     RR 1
# 40839  PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 40841  PROSECUTORIAL DISTRICT 7     ENF-3    ENF 3
#
# [20446 rows x 67 columns]

# %%
import uuid
import json

def perturb_record_with_id(record, original_id):
    perturbed1 = record.copy()
    perturbed2 = record.copy()
    
    perturbed1['last_name'] = perturbed1['last_name'].lower()
    perturbed2['age_at_year_end'] += 1

    new_id1 = f"novo1{original_id}"
    new_id2 = f"novo2{original_id}"
    
    perturbed1['id'] = new_id1
    perturbed2['id'] = new_id2

    return [(new_id1, perturbed1), (new_id2, perturbed2)]

ground_truth = {}
perturbed_records = []

for idx, record in df_selected.iterrows():
    original_id = record['ncid']
    perturbed = perturb_record_with_id(record, original_id)
    for new_id, perturbed_record in perturbed:
        ground_truth[new_id] = original_id
        perturbed_records.append(perturbed_record)

# Export ground truth to CSV
with open('ground_truth.csv', 'w') as f:
    for original_id, new_id in ground_truth.items():
        f.write(f"{original_id},{new_id}\n")

# Create DataFrame for perturbed records and export to CSV
df_perturbed = pd.DataFrame(perturbed_records)
df_perturbed.to_csv('perturbed_records.csv', index=False)

# %%
ground_truth
# Out:
# {'BZ73617': 'novo2BZ73617', 'BZ45167': 'novo2BZ45167'}

# %%
df_perturbed.to_csv('perturbed_records.csv', index=False)

# %%
df_perturbed
# Out:
#        county_id county_desc  voter_reg_num      ncid   last_name first_name  \
# 2             42     HALIFAX         104490   BZ73617     abakkal      NOURA
# 2             42     HALIFAX         104490   BZ73617     ABAKKAL      NOURA
# 4             42     HALIFAX          68003   BZ45167      abbott        AMY
# 4             42     HALIFAX          68003   BZ45167      ABBOTT        AMY
# 6             42     HALIFAX          65983   BZ43147      abbott     DAMIEN
# ...          ...         ...            ...       ...         ...        ...
# 40838         42     HALIFAX         106555   BZ74992     ZUBAIDI       AFAF
# 40839         42     HALIFAX          21018   BZ10671      zucker     DIANNE
# 40839         42     HALIFAX          21018   BZ10671      ZUCKER     DIANNE
# 40841         42     HALIFAX         110115  EH271079  zumbrunnen     DANIEL
# 40841         42     HALIFAX         110115  EH271079  ZUMBRUNNEN     DANIEL
#
#          middle_name name_suffix_lbl status_cd voter_status_desc  ...  \
# 2                NaN             NaN         A            ACTIVE  ...
# 2                NaN             NaN         A            ACTIVE  ...
# 4              CLARY             NaN         D            DENIED  ...
# 4              CLARY             NaN         D            DENIED  ...
# 6                  S             NaN         A            ACTIVE  ...
# ...              ...             ...       ...               ...  ...
# 40838  MOHAMED SALEH             NaN         A            ACTIVE  ...
# 40839            NaN             NaN         A            ACTIVE  ...
# 40839            NaN             NaN         A            ACTIVE  ...
# 40841            NaN              JR         A            ACTIVE  ...
# 40841            NaN              JR         A            ACTIVE  ...
#
#             sanit_dist_desc rescue_dist_abbrv rescue_dist_desc  \
# 2      RR SANITARY DISTRICT               NaN              NaN
# 2      RR SANITARY DISTRICT               NaN              NaN
# 4                       NaN               NaN              NaN
# 4                       NaN               NaN              NaN
# 6                       NaN               NaN              NaN
# ...                     ...               ...              ...
# 40838  RR SANITARY DISTRICT               NaN              NaN
# 40839  RR SANITARY DISTRICT               NaN              NaN
# 40839  RR SANITARY DISTRICT               NaN              NaN
# 40841                   NaN               NaN              NaN
# 40841                   NaN               NaN              NaN
#
#       munic_dist_abbrv         munic_dist_desc  dist_1_abbrv  \
# 2                   RR  CITY OF ROANOKE RAPIDS           7.0
# 2                   RR  CITY OF ROANOKE RAPIDS           7.0
# 4                  NaN                     NaN           NaN
# 4                  NaN                     NaN           NaN
# 6                  NaN                     NaN           7.0
# ...                ...                     ...           ...
# 40838               RR  CITY OF ROANOKE RAPIDS           7.0
# 40839               RR  CITY OF ROANOKE RAPIDS           7.0
# 40839               RR  CITY OF ROANOKE RAPIDS           7.0
# 40841              ENF         TOWN OF ENFIELD           7.0
# 40841              ENF         TOWN OF ENFIELD           7.0
#
#                     dist_1_desc vtd_abbrv vtd_desc           id
# 2      PROSECUTORIAL DISTRICT 7     RR-10    RR 10  novo1104490
# 2      PROSECUTORIAL DISTRICT 7     RR-10    RR 10  novo2104490
# 4                           NaN       NaN      NaN   novo168003
# 4                           NaN       NaN      NaN   novo268003
# 6      PROSECUTORIAL DISTRICT 7     LIT-1    LIT 1   novo165983
# ...                         ...       ...      ...          ...
# 40838  PROSECUTORIAL DISTRICT 7      RR-1     RR 1  novo2106555
# 40839  PROSECUTORIAL DISTRICT 7     RR-10    RR 10   novo121018
# 40839  PROSECUTORIAL DISTRICT 7     RR-10    RR 10   novo221018
# 40841  PROSECUTORIAL DISTRICT 7     ENF-3    ENF 3  novo1110115
# 40841  PROSECUTORIAL DISTRICT 7     ENF-3    ENF 3  novo2110115
#
# [40892 rows x 68 columns]

# %%
truth
# Out:
#        104490  novo2104490
# 0       68003   novo268003
# 1       65983   novo265983
# 2       92176   novo292176
# 3       83239   novo283239
# 4      106195  novo2106195
# ...       ...          ...
# 20440  102061  novo2102061
# 20441  107670  novo2107670
# 20442  106555  novo2106555
# 20443   21018   novo221018
# 20444  110115  novo2110115
#
# [20445 rows x 2 columns]

# %%
def perturb_record(record):
    perturbed1 = record.copy()
    perturbed2 = record.copy()
    
    perturbed1['last_name'] = perturbed1['last_name'].lower()
    perturbed2['age_at_year_end'] += 1

    return [perturbed1, perturbed2]

perturbed_records = []
for _, record in df_selected.iterrows():
    perturbed_records.extend(perturb_record(record))

# Passo 3: Criar o DataFrame B
df_b = pd.DataFrame(perturbed_records)

# %%
df_b
# Out:
#        county_id county_desc  voter_reg_num      ncid   last_name first_name  \
# 2             42     HALIFAX         104490   BZ73617     abakkal      NOURA
# 2             42     HALIFAX         104490   BZ73617     ABAKKAL      NOURA
# 4             42     HALIFAX          68003   BZ45167      abbott        AMY
# 4             42     HALIFAX          68003   BZ45167      ABBOTT        AMY
# 6             42     HALIFAX          65983   BZ43147      abbott     DAMIEN
# ...          ...         ...            ...       ...         ...        ...
# 40838         42     HALIFAX         106555   BZ74992     ZUBAIDI       AFAF
# 40839         42     HALIFAX          21018   BZ10671      zucker     DIANNE
# 40839         42     HALIFAX          21018   BZ10671      ZUCKER     DIANNE
# 40841         42     HALIFAX         110115  EH271079  zumbrunnen     DANIEL
# 40841         42     HALIFAX         110115  EH271079  ZUMBRUNNEN     DANIEL
#
#          middle_name name_suffix_lbl status_cd voter_status_desc  ...  \
# 2                NaN             NaN         A            ACTIVE  ...
# 2                NaN             NaN         A            ACTIVE  ...
# 4              CLARY             NaN         D            DENIED  ...
# 4              CLARY             NaN         D            DENIED  ...
# 6                  S             NaN         A            ACTIVE  ...
# ...              ...             ...       ...               ...  ...
# 40838  MOHAMED SALEH             NaN         A            ACTIVE  ...
# 40839            NaN             NaN         A            ACTIVE  ...
# 40839            NaN             NaN         A            ACTIVE  ...
# 40841            NaN              JR         A            ACTIVE  ...
# 40841            NaN              JR         A            ACTIVE  ...
#
#       sanit_dist_abbrv       sanit_dist_desc rescue_dist_abbrv  \
# 2                  SAN  RR SANITARY DISTRICT               NaN
# 2                  SAN  RR SANITARY DISTRICT               NaN
# 4                  NaN                   NaN               NaN
# 4                  NaN                   NaN               NaN
# 6                  NaN                   NaN               NaN
# ...                ...                   ...               ...
# 40838              SAN  RR SANITARY DISTRICT               NaN
# 40839              SAN  RR SANITARY DISTRICT               NaN
# 40839              SAN  RR SANITARY DISTRICT               NaN
# 40841              NaN                   NaN               NaN
# 40841              NaN                   NaN               NaN
#
#       rescue_dist_desc munic_dist_abbrv         munic_dist_desc dist_1_abbrv  \
# 2                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 2                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 4                  NaN              NaN                     NaN          NaN
# 4                  NaN              NaN                     NaN          NaN
# 6                  NaN              NaN                     NaN          7.0
# ...                ...              ...                     ...          ...
# 40838              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40839              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40839              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40841              NaN              ENF         TOWN OF ENFIELD          7.0
# 40841              NaN              ENF         TOWN OF ENFIELD          7.0
#
#                     dist_1_desc vtd_abbrv vtd_desc
# 2      PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 2      PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 4                           NaN       NaN      NaN
# 4                           NaN       NaN      NaN
# 6      PROSECUTORIAL DISTRICT 7     LIT-1    LIT 1
# ...                         ...       ...      ...
# 40838  PROSECUTORIAL DISTRICT 7      RR-1     RR 1
# 40839  PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 40839  PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 40841  PROSECUTORIAL DISTRICT 7     ENF-3    ENF 3
# 40841  PROSECUTORIAL DISTRICT 7     ENF-3    ENF 3
#
# [40892 rows x 67 columns]

# %%
df_b.to_csv('ncvoter42_perturbed.csv', index=False)

# %%
data.to_csv('ncvoter42.csv', index=False)
