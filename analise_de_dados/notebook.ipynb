# %%
import pandas as pd
import time
import random
import math
import mmh3

# %%
def str_to_MinHash(str1, q, seed=0):
    return min([mmh3.hash(str1[i:i + q], seed) for i in range(len(str1) - q + 1)])

def frequent2(temp, L, t):
    return {k: v for (k, v) in temp.items() if v/L >= t}

# %%
def topK():
       global tp, fp, pairsNo, dictB, L, q
       for index2 in range(nbS, nbS+offsetB):
            if index2 >= len(df2):
               return True
            rr = df2.iloc[index2, 0:3]
            idScholar = rr["id"]
            title = rr["title"]
            authors = rr["authors"]
            srec = title + " " + authors
            temp = dict()
            indices = [random.randrange(0, L) for i in range(L1)]
            K = 5
            topK = [0] * K
            topKIds = [None] * K
            for l in indices:
                key = str(str_to_MinHash(srec.lower(), 2, l))
                d = dictB[l]
                if key in d:
                    ids = d[key]
                    for id in ids:
                        if id in temp:
                           temp[id] += 1
                        else:
                           temp[id] = 1

            for id in temp.keys():
               if temp[id] / L1 >= t:
                   for i in range(K):
                       if topK[i] <= temp[id]:
                         topK.insert(i, temp[id])
                         topK.pop()
                         topKIds.insert(i, id)
                         topKIds.pop()
                         break

            for id_1 in topKIds:
                if id_1 in truthD:
                    ids = truthD[id_1]
                    if idScholar in ids:
                          tp += 1
                    else:
                          fp += 1
       return False

# %%
df1 = pd.read_csv("./copia/DBLP_copy.csv", sep=",", encoding="utf-8", keep_default_na=False)
df2 = pd.read_csv("./copia/Scholar_copy.csv", sep=",", encoding="utf-8", keep_default_na=False)
truth = pd.read_csv("./copia/truth_copy.csv", sep=",", encoding="utf-8", keep_default_na=False)

# %%
df1
# Out:
#                                    id  \
# 0        conf/vldb/RusinkiewiczKTWM95
# 1        journals/sigmod/EisenbergM02
# 2                conf/vldb/AmmannJR95
# 3  conf/sigmod/AbadiCCCCEGHMRSSTXYZ03
#
#                                                title  \
# 0  Towards a Cooperative Transaction Model - The ...
# 1                    SQL/XML is Making Good Progress
# 2  Using Formal Methods to Reason about Semantics...
# 3            Aurora: A Data Stream Management System
#
#                                              authors              venue  year
# 0   M Rusinkiewicz, W Klas, T Tesch, J Wδsch, P Muth               VLDB  1995
# 1                              A Eisenberg, J Melton      SIGMOD Record  2002
# 2                         P Ammann, S Jajodia, I Ray               VLDB  1995
# 3  D Abadi, D Carney, U Ηetintemel, M Cherniack, ...  SIGMOD Conference  2003

# %%
truthD = dict()
for i, r in truth.iterrows():
    idDBLP = r["idDBLP"]
    idScholar = r["idScholar"]
    if idDBLP in truthD:
        ids = truthD[idDBLP]
        ids.append(idScholar)
    else:
        truthD[idDBLP] = [idScholar]
truthD
# Out:
# {'conf/vldb/RusinkiewiczKTWM95': ['019zSr3Lx4EJ',
#   'iWNLOYCQX-YJ',
#   'KureLsKbUXYJ',
#   'T2fm7Wb1ak4J'],
#  'journals/sigmod/EisenbergM02': ['wgK6p4mDSIMJ'],
#  'conf/vldb/AmmannJR95': ['x-H7BqZ0Hw8J'],
#  'conf/sigmod/AbadiCCCCEGHMRSSTXYZ03': ['eBnT7lhV2LwJ',
#   'gBVNSFeS4P8J',
#   'VuY9Y49GqXgJ']}

# %%
t = 0.5
p1 = (t) ** 8
L = math.ceil(math.log(0.1) / math.log(1 - p1))
# print("Minhash LSH=", L)
TP = 5347
eps = 0.1
w = 1000
delta = 0.1
L = math.ceil(math.log(1 / delta) / (2 * (eps ** 2)))
eps = 0.01
L1 = int(1 / (2 * eps))
print("L=", L, "L1=", L1)
q = 2
dictB = [dict() for l in range(L)]
tp = 0
fp = 0
pairsNo = 0
nbS = 1
naS = 1
offsetA = 1
offsetB = 1
indices = [random.randint(0, L) for i in range(L1)]
blockingTime = 0
matchingTime = 0
# Out:
# L= 116 L1= 50

# %%
def matching():
    global tp, fp, pairsNo, L1, q
    for index2 in range(nbS, nbS + offsetB):  # DBLP
        if index2 > len(df2) - 1:
            return True

        rr = df2.iloc[index2, 0:3]
        idScholar = rr["id"]
        title = rr["title"]
        srec = title + " " + rr["authors"]

        temp = dict()
        indices = [random.randrange(0, L) for i in range(L1)]
        matchingPairs = {}
        for l in indices:
            key = str(str_to_MinHash(srec.lower(), q, l))
            d = dictB[l]
            if key in d:
                ids = d[key]
                for id in ids:
                    if id in temp:
                        temp[id] += 1
                        if temp[id] / L1 >= t:
                            matchingPairs[id] = 1
                    else:
                        temp[id] = 1
        for id in matchingPairs.keys():
            idDBLP = id
            pairsNo += 1
            if idDBLP in truthD:
                ids = truthD[idDBLP]
                for id in ids:
                    if id == idScholar:
                        tp += 1
                        break
            else:
                fp += 1

    return False

# %%
while True:
    st = time.time()
    for index1 in range(naS, naS + offsetA):  # Scholar
        if index1 >= len(df1):
            print("chegou")
            break
        rr = df1.iloc[index1, 0:3]
        idDBLP = rr["id"]
        title = rr["title"]
        srec = title + " " + rr["authors"]
        key = ""
        print(srec)
        for l in range(L):
            key = str(str_to_MinHash(srec.lower(), 2, l)) #len(key) = 11
            d = dictB[l]
            if key in d:
                ids = d[key]
                if len(ids) < w:
                    ids.append(df1.iloc[index1, 0])
                else:
                    ids.pop(0)
                    ids.append(df1.iloc[index1, 0])
            else:
                d[key] = [df1.iloc[index1, 0]]
    end = time.time()

    blockingTime += (end - st)
    st = time.time()
    termination = matching()  
    end = time.time()
    matchingTime += (end - st)

    if termination:
            break

    nbS += offsetB
    naS += offsetA
# Out:
# chegou

# %%
#Execução Padrão, com 
print("offsetA", offsetA, "offsetB", offsetB)
print("blocking time (in mins)", blockingTime / 60)
print("matching time (in mins)", matchingTime / 60)
if tp + fp > 0:
    recall = tp / TP
    precision = tp / (tp + fp)
    print("TP=", tp, "Recall=", recall, "Precision=", precision, "pairsNo=", pairsNo, "F1-Score=", 2 * ((precision * recall)/ (precision + recall)))
# Out:
# offsetA 1 offsetB 1
# blocking time (in mins) 0.00027987162272135414
# matching time (in mins) 0.00017440319061279297
# TP= 5 Recall= 0.0009351037965214139 Precision= 1.0 pairsNo= 5 F1-Score= 0.0018684603886397607

# %%
import logging
import sys

from pyflink.common import Types
from pyflink.datastream import StreamExecutionEnvironment
from pyflink.table import (DataTypes, TableDescriptor, Schema, StreamTableEnvironment)
from pyflink.table.expressions import col
from pyflink.table.udf import udf


def mixing_use_of_datastream_and_table():
    # use StreamTableEnvironment instead of TableEnvironment when mixing use of table & datastream
    env = StreamExecutionEnvironment.get_execution_environment()
    t_env = StreamTableEnvironment.create(stream_execution_environment=env)

    # define the source
    t_env.create_temporary_table(
        'source',
        TableDescriptor.for_connector('datagen')
                       .schema(Schema.new_builder()
                               .column('id', DataTypes.BIGINT())
                               .column('data', DataTypes.STRING())
                               .build())
                       .option("number-of-rows", "10")
                       .build())

    # define the sink
    t_env.create_temporary_table(
        'sink',
        TableDescriptor.for_connector('print')
                       .schema(Schema.new_builder()
                               .column('a', DataTypes.BIGINT())
                               .build())
                       .build())

    @udf(result_type=DataTypes.BIGINT())
    def length(data):
        return len(data)

    # perform table api operations
    table = t_env.from_path("source")
    table = table.select(col('id'), length(col('data')))

    # convert table to datastream and perform datastream api operations
    ds = t_env.to_data_stream(table)
    ds = ds.map(lambda i: i[0] + i[1], output_type=Types.LONG())

    # convert datastream to table and perform table api operations as you want
    table = t_env.from_data_stream(
        ds,
        Schema.new_builder().column("f0", DataTypes.BIGINT()).build())

    # execute
    table.execute_insert('sink') \
         .wait()
    # remove .wait if submitting to a remote cluster, refer to
    # https://nightlies.apache.org/flink/flink-docs-stable/docs/dev/python/faq/#wait-for-jobs-to-finish-when-executing-jobs-in-mini-cluster
    # for more details


if __name__ == '__main__':
    logging.basicConfig(stream=sys.stdout, level=logging.INFO, format="%(message)s")

    mixing_use_of_datastream_and_table()
# Out:
# Using Any for unsupported type: typing.Sequence[~T]
# No module named google.cloud.bigquery_storage_v1. As a result, the ReadFromBigQuery transform *CANNOT* be used with `method=DIRECT_READ`.
# KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/py4j/java_gateway.py", line 1217, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 64
#      61 if __name__ == '__main__':
#      62     logging.basicConfig(stream=sys.stdout, level=logging.INFO, format="%(message)s")
# ---> 64     mixing_use_of_datastream_and_table()
#
# Cell In[6], line 55, in mixing_use_of_datastream_and_table()
#      49 table = t_env.from_data_stream(
#      50     ds,
#      51     Schema.new_builder().column("f0", DataTypes.BIGINT()).build())
#      53 # execute
#      54 table.execute_insert('sink') \
# ---> 55      .wait()
#
# File ~/miniconda3/lib/python3.11/site-packages/pyflink/table/table_result.py:76, in TableResult.wait(self, timeout_ms)
#      74     get_method(self._j_table_result, "await")(timeout_ms, TimeUnit.MILLISECONDS)
#      75 else:
# ---> 76     get_method(self._j_table_result, "await")()
#
# File ~/miniconda3/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/miniconda3/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/miniconda3/lib/python3.11/site-packages/py4j/java_gateway.py:1217, in GatewayConnection.send_command(self, command)
#    1213     raise Py4JNetworkError(
#    1214         "Error while sending", e, proto.ERROR_ON_SEND)
#    1216 try:
# -> 1217     answer = smart_decode(self.stream.readline()[:-1])
#    1218     logger.debug("Answer received: {0}".format(answer))
#    1219     if answer.startswith(proto.RETURN_MESSAGE):
#
# File ~/miniconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
# Exception in thread read_grpc_client_inputs:
# Traceback (most recent call last):
#   File "/home/igor/miniconda3/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# Exception in thread read_grpc_client_inputs:
# Traceback (most recent call last):
#   File "/home/igor/miniconda3/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/home/igor/miniconda3/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/apache_beam/runners/worker/data_plane.py", line 669, in <lambda>
#     target=lambda: self._read_inputs(elements_iterator),
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/apache_beam/runners/worker/data_plane.py", line 652, in _read_inputs
#     for elements in elements_iterator:
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/grpc/_channel.py", line 542, in __next__
#     return self._next()
#            ^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/grpc/_channel.py", line 968, in _next
#     raise self
# grpc._channel._MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.CANCELLED
# 	details = "Multiplexer hanging up"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B::1%5D:35619 {grpc_message:"Multiplexer hanging up", grpc_status:1, created_time:"2024-05-21T10:15:00.401884007-03:00"}"
# >
#     self.run()
#   File "/home/igor/miniconda3/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/apache_beam/runners/worker/data_plane.py", line 669, in <lambda>
#     target=lambda: self._read_inputs(elements_iterator),
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/apache_beam/runners/worker/data_plane.py", line 652, in _read_inputs
#     for elements in elements_iterator:
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/grpc/_channel.py", line 542, in __next__
#     return self._next()
#            ^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/grpc/_channel.py", line 968, in _next
#     raise self
# grpc._channel._MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.CANCELLED
# 	details = "Multiplexer hanging up"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B::1%5D:40815 {grpc_message:"Multiplexer hanging up", grpc_status:1, created_time:"2024-05-21T10:15:00.396013345-03:00"}"
# >
# Exception in thread read_grpc_client_inputs:
# Traceback (most recent call last):
#   File "/home/igor/miniconda3/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/home/igor/miniconda3/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/apache_beam/runners/worker/data_plane.py", line 669, in <lambda>
#     target=lambda: self._read_inputs(elements_iterator),
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/apache_beam/runners/worker/data_plane.py", line 652, in _read_inputs
#     for elements in elements_iterator:
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/grpc/_channel.py", line 542, in __next__
#     return self._next()
#            ^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/grpc/_channel.py", line 968, in _next
#     raise self
# grpc._channel._MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.CANCELLED
# 	details = "Multiplexer hanging up"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B::1%5D:37637 {grpc_message:"Multiplexer hanging up", grpc_status:1, created_time:"2024-05-21T10:15:00.401027573-03:00"}"
# >
# Exception in thread read_grpc_client_inputs:
# Traceback (most recent call last):
#   File "/home/igor/miniconda3/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/home/igor/miniconda3/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/apache_beam/runners/worker/data_plane.py", line 669, in <lambda>
#     target=lambda: self._read_inputs(elements_iterator),
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/apache_beam/runners/worker/data_plane.py", line 652, in _read_inputs
#     for elements in elements_iterator:
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/grpc/_channel.py", line 542, in __next__
#     return self._next()
#            ^^^^^^^^^^^^
#   File "/home/igor/miniconda3/lib/python3.11/site-packages/grpc/_channel.py", line 968, in _next
#     raise self
# grpc._channel._MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.CANCELLED
# 	details = "Multiplexer hanging up"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B::1%5D:39767 {created_time:"2024-05-21T10:15:00.486567801-03:00", grpc_status:1, grpc_message:"Multiplexer hanging up"}"
# >
# 5> +I[2866735578586270930]
# 3> +I[-5977226134882793068]
# 9> +I[-214587660841360983]
# 4> +I[-5544873727434937957]
# 10> +I[-8752139827143782728]
# 2> +I[-4329604452233575483]
# 1> +I[-6628258432766251696]
# 8> +I[7561179697052145462]
# 6> +I[3272481767206754291]
# 7> +I[-4193229494577812445]

# %%
import pandas as pd

# %%
df1_db = pd.read_csv("DBLP.csv", sep=",", encoding="utf-8", keep_default_na=False)
df2_sc = pd.read_csv("Scholar.csv", sep=",", encoding="utf-8", keep_default_na=False)

# %%
df1_db["source"] = "dblp"
df1_db
# Out:
#                                 id  \
# 0     conf/vldb/RusinkiewiczKTWM95
# 1     journals/sigmod/EisenbergM02
# 2             conf/vldb/AmmannJR95
# 3            journals/sigmod/Liu02
# 4         journals/sigmod/Hammer02
# ...                            ...
# 2611         conf/vldb/ShuklaDNR96
# 2612      journals/sigmod/Aberer03
# 2613     conf/vldb/RamakrishnanR96
# 2614          conf/vldb/ShaferAM96
# 2615     journals/sigmod/Aberer03a
#
#                                                   title  \
# 0     Towards a Cooperative Transaction Model - The ...
# 1                       SQL/XML is Making Good Progress
# 2     Using Formal Methods to Reason about Semantics...
# 3                                        Editor's Notes
# 4     Report on the ACM Fourth International Worksho...
# ...                                                 ...
# 2611  Storage Estimation for Multidimensional Aggreg...
# 2612                              Call for Book Reviews
# 2613                           Modeling Design Versions
# 2614  SPRINT: A Scalable Parallel Classifier for Dat...
# 2615  Report on the First International Conference o...
#
#                                                authors          venue  year  \
# 0     M Rusinkiewicz, W Klas, T Tesch, J Wδsch, P Muth           VLDB  1995
# 1                                A Eisenberg, J Melton  SIGMOD Record  2002
# 2                           P Ammann, S Jajodia, I Ray           VLDB  1995
# 3                                                L Liu  SIGMOD Record  2002
# 4                                                  N/A            N/A  2002
# ...                                                ...            ...   ...
# 2611     A Shukla, P Deshpande, J Naughton, K Ramasamy           VLDB  1996
# 2612                                               N/A            N/A  2003
# 2613                             R Ramakrishnan, D Ram           VLDB  1996
# 2614                      J Shafer, R Agrawal, M Mehta           VLDB  1996
# 2615                                               N/A            N/A  2003
#
#      source
# 0      dblp
# 1      dblp
# 2      dblp
# 3      dblp
# 4      dblp
# ...     ...
# 2611   dblp
# 2612   dblp
# 2613   dblp
# 2614   dblp
# 2615   dblp
#
# [2616 rows x 6 columns]

# %%
df2_sc["source"] = "scholar"
df2_sc
# Out:
#                                                       id  \
# 0                                           aKcZKwvwbQwJ
# 1                                           ixKfiTHoaDoJ
# 2                                           3BxllB4wwcIJ
# 3                                           d2WWxwKMex4J
# 4                                           cZCX-AQpjccJ
# ...                                                  ...
# 64258                                       TX4SGKJQUiEJ
# 64259  url:http://portal.acm.org/citation.cfm%3Fid%3D...
# 64260                                       7Hi3KKsxKNwJ
# 64261  url:http://portal.acm.org/citation.cfm%3Fid%3D...
# 64262                                       U2fYU71slN8J
#
#                                                    title  \
# 0                             11578 Sorrento Valley Road
# 1                    Initiation of crazes in polystyrene
# 2      Immunogold labelling is a quantitative method ...
# 3      The Burden of Infectious Disease Among Inmates...
# 4      The Role of Faculty Advising in Science and En...
# ...                                                  ...
# 64258                             Theophylline toxicity.
# 64259  Source ACM Transactions on Database Systems (T...
# 64260  Range Nesting: A Fast Method to Evaluate Quant...
# 64261  Source ACM Transactions on Database Systems (T...
# 64262  A Declarative Approach to Optimize Bulk Loadin...
#
#                                                 authors  \
# 0                                                QD Inc
# 1                                 AS Argon, JG Hannoosh
# 2      GH Hansen, LL Wetterberg, H SjÃ¶strÃ¶m, O NorÃ©n
# 3                        TM Hammett, P Harmon, W Rhodes
# 4                                            JR Cogdell
# ...                                                 ...
# 64258                                        DS Cooling
# 64259                                         RW Taylor
# 64260                                   M Jarke, J Koch
# 64261                                             W Kim
# 64262                             S Amer-Yahia, S Cluet
#
#                                               venue  year   source
# 0                                        San Diego,        scholar
# 1                                        Phil. Mag,        scholar
# 2                        The Histochemical Journal,  1992  scholar
# 3                                               see        scholar
# 4         NEW DIRECTIONS FOR TEACHING AND LEARNING,  1995  scholar
# ...                                             ...   ...      ...
# 64258                Journal of Emergency Medicine,  1993  scholar
# 64259  ACM Transactions on Database Systems (TODS),  1983  scholar
# 64260                                                      scholar
# 64261  ACM Transactions on Database Systems (TODS),  1993  scholar
# 64262         ACM Transactions on Database Systems,  2004  scholar
#
# [64263 rows x 6 columns]

# %%
df3 = pd.concat([df1_db, df2_sc], axis=0)
df3
# Out:
#                                                       id  \
# 0                           conf/vldb/RusinkiewiczKTWM95
# 1                           journals/sigmod/EisenbergM02
# 2                                   conf/vldb/AmmannJR95
# 3                                  journals/sigmod/Liu02
# 4                               journals/sigmod/Hammer02
# ...                                                  ...
# 64258                                       TX4SGKJQUiEJ
# 64259  url:http://portal.acm.org/citation.cfm%3Fid%3D...
# 64260                                       7Hi3KKsxKNwJ
# 64261  url:http://portal.acm.org/citation.cfm%3Fid%3D...
# 64262                                       U2fYU71slN8J
#
#                                                    title  \
# 0      Towards a Cooperative Transaction Model - The ...
# 1                        SQL/XML is Making Good Progress
# 2      Using Formal Methods to Reason about Semantics...
# 3                                         Editor's Notes
# 4      Report on the ACM Fourth International Worksho...
# ...                                                  ...
# 64258                             Theophylline toxicity.
# 64259  Source ACM Transactions on Database Systems (T...
# 64260  Range Nesting: A Fast Method to Evaluate Quant...
# 64261  Source ACM Transactions on Database Systems (T...
# 64262  A Declarative Approach to Optimize Bulk Loadin...
#
#                                                 authors  \
# 0      M Rusinkiewicz, W Klas, T Tesch, J Wδsch, P Muth
# 1                                 A Eisenberg, J Melton
# 2                            P Ammann, S Jajodia, I Ray
# 3                                                 L Liu
# 4                                                   N/A
# ...                                                 ...
# 64258                                        DS Cooling
# 64259                                         RW Taylor
# 64260                                   M Jarke, J Koch
# 64261                                             W Kim
# 64262                             S Amer-Yahia, S Cluet
#
#                                               venue  year   source
# 0                                              VLDB  1995     dblp
# 1                                     SIGMOD Record  2002     dblp
# 2                                              VLDB  1995     dblp
# 3                                     SIGMOD Record  2002     dblp
# 4                                               N/A  2002     dblp
# ...                                             ...   ...      ...
# 64258                Journal of Emergency Medicine,  1993  scholar
# 64259  ACM Transactions on Database Systems (TODS),  1983  scholar
# 64260                                                      scholar
# 64261  ACM Transactions on Database Systems (TODS),  1993  scholar
# 64262         ACM Transactions on Database Systems,  2004  scholar
#
# [66879 rows x 6 columns]

# %%
df3 = df3.astype(str)

# %%
df3.to_csv("df__full_merged.csv",index=False)

# %%
import pandas as pd
df_xml = pd.read_xml("/home/igor/Downloads/dblp.xml")
df_xml
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# Define uma função para processar cada elemento
def process_element(element):
    data = {
        'col1': element.find('col1').text,
        'col2': element.find('col2').text,
        'col3': element.find('col3').text
    }
    return data

# Caminho para o arquivo XML
file_path = '/home/igor/Downloads/dblp.xml'

# Lista para armazenar os dados
data = []

# Itera sobre os elementos do arquivo XML
for event, elem in ET.iterparse(file_path, events=('end',), tag='record'):
    data.append(process_element(elem))
    elem.clear()  # Limpa o elemento para liberar memória

# Converte a lista de dados para um DataFrame do pandas
df = pd.DataFrame(data)

print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 20
#      17 data = []
#      19 # Itera sobre os elementos do arquivo XML
# ---> 20 for event, elem in ET.iterparse(file_path, events=('end',), tag='record'):
#      21     data.append(process_element(elem))
#      22     elem.clear()  # Limpa o elemento para liberar memória
#
# TypeError: iterparse() got an unexpected keyword argument 'tag'

# %%
import pandas as pd

# %%
df_txt = pd.read_table("ncvoter42.txt",encoding='unicode_escape')
df_txt
# Out:
#        county_id county_desc  voter_reg_num      ncid   last_name first_name  \
# 0             42     HALIFAX         100702   BZ61829       AARON     RHANDA
# 1             42     HALIFAX         107751   BZ75895       AASBY    BRANDON
# 2             42     HALIFAX         104490   BZ73617     ABAKKAL      NOURA
# 3             42     HALIFAX          97201   BZ68595       ABBAN    SHANNAN
# 4             42     HALIFAX          68003   BZ45167      ABBOTT        AMY
# ...          ...         ...            ...       ...         ...        ...
# 40837         42     HALIFAX         107670   BZ45511   ZSEBEHAZY     ROBERT
# 40838         42     HALIFAX         106555   BZ74992     ZUBAIDI       AFAF
# 40839         42     HALIFAX          21018   BZ10671      ZUCKER     DIANNE
# 40840         42     HALIFAX          21011   BZ10666      ZUCKER     ROBERT
# 40841         42     HALIFAX         110115  EH271079  ZUMBRUNNEN     DANIEL
#
#          middle_name name_suffix_lbl status_cd voter_status_desc  ...  \
# 0        FAITH THORA             NaN         A            ACTIVE  ...
# 1                NaN             NaN         A            ACTIVE  ...
# 2                NaN             NaN         A            ACTIVE  ...
# 3              JANAY             NaN         I          INACTIVE  ...
# 4              CLARY             NaN         D            DENIED  ...
# ...              ...             ...       ...               ...  ...
# 40837           JOHN             NaN         A            ACTIVE  ...
# 40838  MOHAMED SALEH             NaN         A            ACTIVE  ...
# 40839            NaN             NaN         A            ACTIVE  ...
# 40840              N             NaN         A            ACTIVE  ...
# 40841            NaN              JR         A            ACTIVE  ...
#
#       sanit_dist_abbrv       sanit_dist_desc rescue_dist_abbrv  \
# 0                  SAN  RR SANITARY DISTRICT               NaN
# 1                  NaN                   NaN               NaN
# 2                  SAN  RR SANITARY DISTRICT               NaN
# 3                  SAN  RR SANITARY DISTRICT               NaN
# 4                  NaN                   NaN               NaN
# ...                ...                   ...               ...
# 40837              NaN                   NaN               NaN
# 40838              SAN  RR SANITARY DISTRICT               NaN
# 40839              SAN  RR SANITARY DISTRICT               NaN
# 40840              SAN  RR SANITARY DISTRICT               NaN
# 40841              NaN                   NaN               NaN
#
#       rescue_dist_desc munic_dist_abbrv         munic_dist_desc dist_1_abbrv  \
# 0                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 1                  NaN              NaN                     NaN          7.0
# 2                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 3                  NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 4                  NaN              NaN                     NaN          NaN
# ...                ...              ...                     ...          ...
# 40837              NaN              NaN                     NaN          7.0
# 40838              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40839              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40840              NaN               RR  CITY OF ROANOKE RAPIDS          7.0
# 40841              NaN              ENF         TOWN OF ENFIELD          7.0
#
#                     dist_1_desc vtd_abbrv vtd_desc
# 0      PROSECUTORIAL DISTRICT 7      RR-8     RR 8
# 1      PROSECUTORIAL DISTRICT 7      RR-9     RR 9
# 2      PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 3      PROSECUTORIAL DISTRICT 7      RR-1     RR 1
# 4                           NaN       NaN      NaN
# ...                         ...       ...      ...
# 40837  PROSECUTORIAL DISTRICT 7     WEL-3    WEL 3
# 40838  PROSECUTORIAL DISTRICT 7      RR-1     RR 1
# 40839  PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 40840  PROSECUTORIAL DISTRICT 7     RR-10    RR 10
# 40841  PROSECUTORIAL DISTRICT 7     ENF-3    ENF 3
#
# [40842 rows x 67 columns]

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/igor/miniconda3/lib/python3.11/site-packages (5.2.2)
